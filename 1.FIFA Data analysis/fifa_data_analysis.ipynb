# %% [markdown]
# # FIFA Data Analysis
#
# ### 1. Introduction
#
# This is an project focused on analysing large tabular dataset. Here I used FIFA dataset that has arround 80 columns of information regarding players, matches etc

# %%
import pandas as pd 

path = "D:\\Coding_Stuff\\GitHub\\Classical_Data_Science\\1.FIFA Data analysis\\data.csv"
data = pd.read_csv(path)

data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
data.describe().T
# Out:
#                             count           mean           std    min  \
# Unnamed: 0                18207.0    9103.000000   5256.052511    0.0
# ID                        18207.0  214298.338606  29965.244204   16.0
# Age                       18207.0      25.122206      4.669943   16.0
# Overall                   18207.0      66.238699      6.908930   46.0
# Potential                 18207.0      71.307299      6.136496   48.0
# Special                   18207.0    1597.809908    272.586016  731.0
# International Reputation  18159.0       1.113222      0.394031    1.0
# Weak Foot                 18159.0       2.947299      0.660456    1.0
# Skill Moves               18159.0       2.361308      0.756164    1.0
# Jersey Number             18147.0      19.546096     15.947765    1.0
# Crossing                  18159.0      49.734181     18.364524    5.0
# Finishing                 18159.0      45.550911     19.525820    2.0
# ...

# %% [markdown]
# ### 2.Data Cleaning

# %%
# dropping unwanted columns 

data.drop(['Unnamed: 0','Photo','Flag','Club Logo'], axis=1, inplace=True)

# %%
# taking stock of missing values 

print(data.isnull().sum())
# Out:
# ID                   0
# Name                 0
# Age                  0
# Nationality          0
# Overall              0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 85, dtype: int64

# %% [markdown]
# The value `48` is repeated several times, let's see if they're of the same `ID` too.
#
# Because since in many columns exactly 48 values are missing there are chances that it can be of same `ID`

# %%
missing_GKHandling = data[data['GKHandling'].isnull()].index.tolist()
missing_GKKicking = data[data['GKKicking'].isnull()].index.tolist()

if missing_GKHandling == missing_GKKicking:
    print("They're the same")
else:
    print("Nope")
# Out:
# They're the same

# %%
data.head(5)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club    Value   Wage  Special  ... Composure  Marking  \
# 0         FC Barcelona  €110.5M  €565K     2202  ...      96.0     33.0
# 1             Juventus     €77M  €405K     2228  ...      95.0     28.0
# 2  Paris Saint-Germain  €118.5M  €290K     2143  ...      94.0     27.0
# 3    Manchester United     €72M  €260K     1471  ...      68.0     15.0
# 4      Manchester City    €102M  €355K     2281  ...      88.0     68.0
#
#    StandingTackle  SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# ...

# %%
# Countries with the heighest number of players 
print("Total number of countries: ", len(data['Nationality'].unique()))
print(data['Nationality'].value_counts().head(5))
print("--"*40)
# Out:
# Total number of countries:  164
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64
# --------------------------------------------------------------------------------

# %% [markdown]
# Europe has the most number of players.

# %%
#Total number of clubs present and Top clubs with heigest number of players

print("Total number of clubs: ", len(data['Club'].unique()))
print("Number of players per club:")
print(data['Club'].value_counts().head(5))
# Out:
# Total number of clubs:  652
# Number of players per club:
# Club
# FC Barcelona          33
# Valencia CF           33
# Fortuna Düsseldorf    33
# Cardiff City          33
# Rayo Vallecano        33
# Name: count, dtype: int64

# %%
# Players with maximum potentail and overall performance
print("Player with overall performance :", data.loc[data['Overall'].argmax()]['Name'])

print("Payer with max potentail: ", data.loc[data['Potential'].argmax()]['Name'])
# Out:
# Player with overall performance : L. Messi
# Payer with max potentail:  K. Mbappé

# %% [markdown]
# MESSI THE GOAT

# %%
# Players who are best in different aspects, i choose 5 of my fav

pr_cols=['Crossing', 'Finishing', 'LongShots',
       'Dribbling', 'BallControl']
print("----BEST IN DIFFERENT ASPECTS----")
for col in pr_cols:
    print(f"Best in {col} is : ", data.loc[data[col].argmax()]['Name'])
# Out:
# ----BEST IN DIFFERENT ASPECTS----
# Best in Crossing is :  K. De Bruyne
# Best in Finishing is :  L. Messi
# Best in LongShots is :  L. Messi
# Best in Dribbling is :  L. Messi
# Best in BallControl is :  L. Messi

# %%
data[['Value','Wage']].head(3)
# Out:
#      Value   Wage
# 0  €110.5M  €565K
# 1     €77M  €405K
# 2  €118.5M  €290K

# %% [markdown]
# These suffixes have to be cleaned up so that we get values to do visualizations and analysis.

# %%
# function to clean player revenues into float values for analysis

def clean_values(data_value):
    try:
        value = float(data_value[1:-1])
        suffix = data_value[-1]
        if suffix == 'M':
            value = value * 100000
        elif suffix == "K":
            value = value * 1000
    except ValueError:
        value = 0

    return value

data['Value'] = data['Value'].apply(clean_values)
data['Wage'] = data['Wage'].apply(clean_values)

# %%
data[['Value','Wage']].head(3)
# Out:
#         Value      Wage
# 0  11050000.0  565000.0
# 1   7700000.0  405000.0
# 2  11850000.0  290000.0

# %%
# Most valuable players and heighest earner
print("Most valuable player: (Market value) ", data.loc[data['Value'].argmax()]['Name'])
print("Heigest earner: ", data.loc[data['Wage'].argmax()]['Name'])
# Out:
# Most valuable player: (Market value)  Neymar Jr
# Heigest earner:  L. Messi

# %% [markdown]
# ### 3. Exploratory Data Analysis

# %%
# Let's see the potential of players w.r.t Age 

import seaborn as sns
import matplotlib.pyplot as plt 

sns.jointplot(x = data['Age'], y=data['Potential'])

# %% [markdown]
# It is visivle that from 22,23 to 26,27 the the players are in theor prime , then their potentail tends to decline. This is true across all sports i belive.
#
# we can test this by looking at player stats like `spintspeed`,`strength`,`value`,`dribbling` etc.

# %%
fig, axe = plt.subplots(2,2)
fig.suptitle('Age vs different aspects')

sns.lineplot(x = data['Age'], y = data['SprintSpeed'], ax=axe[0,0])
sns.lineplot(x = data['Age'], y = data['Strength'], ax=axe[0,1])
sns.lineplot(x = data['Age'], y = data['Value'], ax=axe[1,0])
sns.lineplot(x = data['Age'], y = data['Dribbling'], ax=axe[1,1])
# Out:
# <Axes: xlabel='Age', ylabel='Dribbling'>

# %% [markdown]
# All shows a downward trend with some exceptional cases like maybe`MESSI`

# %% [markdown]
# ### 4.Modeling

# %%
data.drop(['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB','Nationality'],inplace=True, axis=1)

# %%
# Drop unessesary values

data = data.drop(['Jersey Number','Joined','Special','Loaned From','Body Type', 'Release Clause','Weight','Height','Contract Valid Until','Wage','Value','Name','Club'], axis = 1)

data.dropna(inplace=True)

data.head()
# Out:
#        ID  Age  Overall  Potential Preferred Foot  International Reputation  \
# 0  158023   31       94         94           Left                       5.0
# 1   20801   33       94         94          Right                       5.0
# 2  190871   26       92         93          Right                       5.0
# 3  193080   27       91         93          Right                       4.0
# 4  192985   27       91         92          Right                       4.0
#
#    Weak Foot  Skill Moves       Work Rate Real Face  ... Penalties  Composure  \
# 0        4.0          4.0  Medium/ Medium       Yes  ...      75.0       96.0
# 1        4.0          5.0       High/ Low       Yes  ...      85.0       95.0
# 2        5.0          5.0    High/ Medium       Yes  ...      81.0       94.0
# 3        3.0          1.0  Medium/ Medium       Yes  ...      40.0       68.0
# 4        5.0          4.0      High/ High       Yes  ...      79.0       88.0
#
# ...

# %%
#Turn Real Face into a binary indicator variable
def face_to_num(df):
    if (df['Real Face'] == 'Yes'):
        return 1
    else:
        return 0
    
#Turn Preferred Foot into a binary indicator variable
def right_footed(df):
    if (df['Preferred Foot'] == 'Right'):
        return 1
    else:
        return 0
    
data["Real Face"] = data.apply(face_to_num, axis=1)
data["Preferred Foot"] = data.apply(right_footed, axis=1)

# %%
data["Work Rate"].head(3)
# Out:
# 0    Medium/ Medium
# 1         High/ Low
# 2      High/ Medium
# Name: Work Rate, dtype: object

# %%
# Split the work rate column

temp = data['Work Rate'].str.split("/ ", n=1, expand=True)
data["Work Rate1"] = temp[0]
data["Work Rate2"] = temp[1]

data.drop(["Work Rate"], axis=1, inplace=True)
data.head(3)
# Out:
#        ID  Age  Overall  Potential  Preferred Foot  International Reputation  \
# 0  158023   31       94         94               0                       5.0
# 1   20801   33       94         94               1                       5.0
# 2  190871   26       92         93               1                       5.0
#
#    Weak Foot  Skill Moves  Real Face Position  ...  Marking  StandingTackle  \
# 0        4.0          4.0          1       RF  ...     33.0            28.0
# 1        4.0          5.0          1       ST  ...     28.0            31.0
# 2        5.0          5.0          1       LW  ...     27.0            24.0
#
#    SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  \
# 0           26.0       6.0        11.0       15.0           14.0         8.0
# 1           23.0       7.0        11.0       15.0           14.0        11.0
# 2           33.0       9.0         9.0       15.0           15.0        11.0
#
#    Work Rate1  Work Rate2
# ...

# %%
#Split ID as a Target value
target = data.Overall
data = data.drop(['Overall'], axis = 1)

#Splitting into test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

#One Hot Encoding
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
print(X_test.shape,X_train.shape)
print(y_test.shape,y_train.shape)
# Out:
# (3630, 75) (14517, 75)
# (3630,) (14517,)

# %%
#Applying Linear Regression
from sklearn.linear_model import LinearRegression
import numpy as np 

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

#Finding the r2 score and root mean squared error
from sklearn.metrics import r2_score, mean_squared_error
print('r2 score: '+str(r2_score(y_test, predictions)))
print('RMSE : '+str(np.sqrt(mean_squared_error(y_test, predictions))))
# Out:
# r2 score: 0.9391956425114959
# RMSE : 1.7041346490075937

# %% [markdown]
# Permutation importance is the first tool for understanding a machine-learning model, and involves shuffling individual variables in the validation data (after a model has been fit), and seeing the effect on accuracy.

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(model, random_state=1).fit(X_test, y_test)
eli5.show_weights(perm, feature_names = X_test.columns.tolist())
#Top 3 important features are Potential, Age & Reactions
